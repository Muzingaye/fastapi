# %%
import requests
# import httpx}

# %%
base_url = "http://localhost:8000"
path = "/events"
endpoint =f"{base_url}{path}"

# %%
resp = requests.get(endpoint)

if resp.ok:
    data = resp.json()
    print(data)
# Out:
# [{'id': 2, 'page': '', 'description': ''}, {'id': 3, 'page': '', 'description': ''}]

# %%
create_endpoint = f'{base_url}/events'
data = {
    "page":"what page",
    "description": "Test Event Update"
}

res = requests.post(
    create_endpoint,
    json={"path": "Test Event"}
)
print(res.status_code)
# print(res.headers)
# print(res.json())
if res.ok:
    res.json()
    print(res.status_code)
# Out:
# 422

# %%
update_endpoint = f'{base_url}/events/12'
data = {
    "page": "ksdlsklds", 
    "description": "Test Event Update"
}

# print(full_endpoint)
res = requests.put(update_endpoint, json= data)
if res.ok:
    res.json()
    print(res.json)
else:
    print(res.status_code)
    print(res.text)
# Out:
# <bound method Response.json of <Response [200]>>
