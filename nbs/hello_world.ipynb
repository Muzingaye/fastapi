# %%
import requests
# import httpx

# %%
base_url = "http://localhost:8000"
path = "/events/12"
endpoint =f"{base_url}{path}"

# %%
resp = requests.get(endpoint)

if resp.ok:
    data = resp.json()
    print(data)
# Out:
# {'id': 12}
